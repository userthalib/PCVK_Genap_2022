# %% [markdown]
# <a href="https://colab.research.google.com/github/userthalib/PCVK_Genap_2022/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten01.jpg' , cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan file
#cv.imwrite('/content/drive/MyDrive/PCVK/Images/mandrill2.tiff',img5)

#menampilkan plot
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#koordinat titik titik
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=(50),color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(400,400),radius=(30),color=(255,0,0),thickness=70)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# TUGAS

# %%
img_grays = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten01.jpg' , cv.IMREAD_GRAYSCALE)
plt.imshow(img_grays, cmap='RdYlGn')

# %%
plt.imshow(img_grays, cmap='GnBu')

# %%
cropped_image = img3[10:100, 10:100]
plt.imshow(cropped_image)

# %%
tinggi = img3.shape[0]
lebar = img3.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi," x ",lebar)
cv2_imshow(img3)
# Out:
# resolusi image: tinggi x lebar =  627  x  670
# <PIL.Image.Image image mode=RGB size=670x627 at 0x7F7B94D18950>

# %%
cropped_image2 = img3[5:30, 0:670]
plt.imshow(cropped_image2, cmap='Greens')

# %%
img5 = np.zeros(shape=(500,500,3),dtype=np.int32)
cv.rectangle(img5,pt1=(400,0),pt2=(500,100),color=(0,255,0),thickness=5)
cv.rectangle(img5,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=5)
cv.rectangle(img5,pt1=(0,0),pt2=(100,100),color=(255,0,0),thickness=5)
cv.rectangle(img5,pt1=(0,500),pt2=(100,400),color=(255,255,255),thickness=5)
cv.rectangle(img5,pt1=(400,500),pt2=(500,400),color=(255,255,0),thickness=5)
plt.imshow(img5)

# %%
imgFlip = cv.flip(img5,0)
plt.imshow(imgFlip)

# %%
img6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img6,pt1=(220,1),pt2=(500,290),color=(0,255,0),thickness=5)
cv.circle(img6,center=(400,150),radius=(100),color=(255,0,0),thickness=5)
plt.imshow(img6)

# %%
img7 = img6
cv.rectangle(img7,pt1=(1,699),pt2=(100,500),color=(0,0,255),thickness=-1)
plt.imshow(img7)
